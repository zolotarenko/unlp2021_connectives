# %%
with open('uk_connectives_cleaned-connectives_cleaned.csv') as con:
    con=list(con)
    con=[e.replace('\n','').split(',')[:9] for e in con]
    con=[e for e in con if len(e)==9]
    connectives=[e[0] for e in con[1:]]
    english=[e[1] for e in con[1:]]
    cont_discont=[e[2] for e in con[1:]]
    single_phrasal=[e[3] for e in con[1:]]
    ortho_variant=[e[4] for e in con[1:]]
    syntax=[e[5] for e in con[1:]]
    sense1=[e[6] for e in con[1:]]
    sense2=[e[7] for e in con[1:]]
    sense3=[e[8] for e in con[1:]]
    two_parted=[e for e in connectives if '...' in e and e!='']
    one_parted=[e for e in connectives if '...'  not in e and e!='' and ' ' not in e]
    two_words=[e for e in connectives if '...'  not in e and e!='' and ' ' in e]
    two_parted=[e.split('...') for e in two_parted if 'не тільки' not in e.split('...')[0]]
    print(two_parted)
    print(one_parted)
    print(two_words)
# Out:
# [['ані', 'ані'], ['ні', 'ні'], ['чим', 'тим'], ['або', 'або']]
# ['а', 'або', 'адже', 'але', 'бо', 'відповідно', 'відразу', 'врешті', 'доки', 'допоки', 'замість', 'згодом', 'зокрема', 'зрештою', 'і', 'інакше', 'коли', 'колись', 'наприклад', 'нарешті', 'насправді', 'настільки', 'натомість', 'однак', 'одночасно', 'окремо', 'окрім', 'оскільки', 'отже', 'перед', 'пізніше', 'після', 'плюс', 'поки', 'потім', 'проте', 'радше', 'раніше', 'скоріше', 'та', 'також', 'теж', 'то', 'тоді', 'тож', 'тому', 'точніше', 'фактично', 'хоч', 'хоча', 'через', 'чи', 'ще', 'як', 'якби', 'якщо', 'ніби', 'зате', 'аби', 'ба', 'буцім', 'відколи', 'втім', 'гейби', 'докіль', 'допіру', 'й', 'мов', 'наче', 'немов', 'неначе', 'нехай', 'нібито', 'ніж', 'одначе', 'отож', 'позаяк', 'притім', 'притому', 'причім', 'раз', 'себто', 'таж', 'так', 'тільки', 'тобто', 'тому-то', 'хай', 'хіба', 'цебто', 'щоби', 'щойно', 'щоправда']
# ['в іншому випадку', 'в той час як', 'в цілому', 'за винятком', 'все ж', 'до того', 'коротко кажучи', 'окрім того', 'крім того', 'не менш', 'не менше', 'незалежно від', 'незважаючи на', 'перш ніж', 'по тому', 'поруч з', 'так що', 'таким чином', 'тим самим', 'тим часом', 'в той же час', 'тому що', 'хіба що', 'в той час як', 'як тільки', 'дарма що', 'а все-таки', 'та все-таки', 'а усе', 'а усе-таки', 'та усе', 'та усе-таки']

# %%
with open('texts.txt','r') as text:
    text=list(text)
    text=[e.replace('\n') for e in text]

# %%
import re
tokenized=[]
for e in text:
    tokenized.append(re.split('[\s.»«!?,]', e))
tokenized=[[i for i in e if i!='']for e in tokenized]
matched=[]
for t in tokenized:
    for w in range(len(t)):
        if t[w].lower() in one_parted:
            print(t[w])
            print(t[w-2:])
            matched.append(t[w])
# Out:
# після
# ['Юрій', 'Ушаков', 'після', 'того', 'як', 'були', 'запроваджені', 'нові', 'американські', 'санкції', 'і', 'вислані', 'з', 'США', 'російські', 'дипломати', 'які', 'займалися', 'шпигунством', 'Російського', 'посла', 'у', 'Вашингтоні', 'немає', 'вже', 'кілька', 'тижнів', '-', 'Москва', 'відкликала', 'Анатолія', 'Антонова', 'після', 'того', 'як', 'президент', 'США', 'Джозеф', 'Байден', 'погодився', 'із', 'точним', 'визначенням', 'Володимира', 'Путіна', 'як', 'вбивці']
# як
# ['після', 'того', 'як', 'були', 'запроваджені', 'нові', 'американські', 'санкції', 'і', 'вислані', 'з', 'США', 'російські', 'дипломати', 'які', 'займалися', 'шпигунством', 'Російського', 'посла', 'у', 'Вашингтоні', 'немає', 'вже', 'кілька', 'тижнів', '-', 'Москва', 'відкликала', 'Анатолія', 'Антонова', 'після', 'того', 'як', 'президент', 'США', 'Джозеф', 'Байден', 'погодився', 'із', 'точним', 'визначенням', 'Володимира', 'Путіна', 'як', 'вбивці']
# і
# ['американські', 'санкції', 'і', 'вислані', 'з', 'США', 'російські', 'дипломати', 'які', 'займалися', 'шпигунством', 'Російського', 'посла', 'у', 'Вашингтоні', 'немає', 'вже', 'кілька', 'тижнів', '-', 'Москва', 'відкликала', 'Анатолія', 'Антонова', 'після', 'того', 'як', 'президент', 'США', 'Джозеф', 'Байден', 'погодився', 'із', 'точним', 'визначенням', 'Володимира', 'Путіна', 'як', 'вбивці']
# після
# ['Анатолія', 'Антонова', 'після', 'того', 'як', 'президент', 'США', 'Джозеф', 'Байден', 'погодився', 'із', 'точним', 'визначенням', 'Володимира', 'Путіна', 'як', 'вбивці']
# як
# ['після', 'того', 'як', 'президент', 'США', 'Джозеф', 'Байден', 'погодився', 'із', 'точним', 'визначенням', 'Володимира', 'Путіна', 'як', 'вбивці']
# як
# ['Володимира', 'Путіна', 'як', 'вбивці']
# Одночасно
# ['службового', 'автомобіля']
# і
# ['громадян', 'Росії', 'і', 'між', 'іншим', 'інших', 'країн', 'теж', 'Якщо', 'враховувати', 'що', 'американські', 'дипломатичні', 'представництва', 'як', 'правило', 'наймають', 'технічних', 'співробітників', 'на', 'місці', 'це', 'стане', 'серйозною', 'проблемою', 'При', 'цьому', 'Росія', 'відмовляє', 'у', 'візах', 'не', 'тільки', 'співробітникам', 'посольств', 'але', 'і', 'технічному', 'персоналу', 'який', 'міг', 'би', 'приїхати', 'з', 'США', 'Так', 'що', 'посольство', 'США', 'у', 'Москві', 'ймовірно', 'буде', 'поставлено', 'в', 'ситуацію', '1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# теж
# ['інших', 'країн', 'теж', 'Якщо', 'враховувати', 'що', 'американські', 'дипломатичні', 'представництва', 'як', 'правило', 'наймають', 'технічних', 'співробітників', 'на', 'місці', 'це', 'стане', 'серйозною', 'проблемою', 'При', 'цьому', 'Росія', 'відмовляє', 'у', 'візах', 'не', 'тільки', 'співробітникам', 'посольств', 'але', 'і', 'технічному', 'персоналу', 'який', 'міг', 'би', 'приїхати', 'з', 'США', 'Так', 'що', 'посольство', 'США', 'у', 'Москві', 'ймовірно', 'буде', 'поставлено', 'в', 'ситуацію', '1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# Якщо
# ['країн', 'теж', 'Якщо', 'враховувати', 'що', 'американські', 'дипломатичні', 'представництва', 'як', 'правило', 'наймають', 'технічних', 'співробітників', 'на', 'місці', 'це', 'стане', 'серйозною', 'проблемою', 'При', 'цьому', 'Росія', 'відмовляє', 'у', 'візах', 'не', 'тільки', 'співробітникам', 'посольств', 'але', 'і', 'технічному', 'персоналу', 'який', 'міг', 'би', 'приїхати', 'з', 'США', 'Так', 'що', 'посольство', 'США', 'у', 'Москві', 'ймовірно', 'буде', 'поставлено', 'в', 'ситуацію', '1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# як
# ['дипломатичні', 'представництва', 'як', 'правило', 'наймають', 'технічних', 'співробітників', 'на', 'місці', 'це', 'стане', 'серйозною', 'проблемою', 'При', 'цьому', 'Росія', 'відмовляє', 'у', 'візах', 'не', 'тільки', 'співробітникам', 'посольств', 'але', 'і', 'технічному', 'персоналу', 'який', 'міг', 'би', 'приїхати', 'з', 'США', 'Так', 'що', 'посольство', 'США', 'у', 'Москві', 'ймовірно', 'буде', 'поставлено', 'в', 'ситуацію', '1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# тільки
# ['візах', 'не', 'тільки', 'співробітникам', 'посольств', 'але', 'і', 'технічному', 'персоналу', 'який', 'міг', 'би', 'приїхати', 'з', 'США', 'Так', 'що', 'посольство', 'США', 'у', 'Москві', 'ймовірно', 'буде', 'поставлено', 'в', 'ситуацію', '1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# але
# ['співробітникам', 'посольств', 'але', 'і', 'технічному', 'персоналу', 'який', 'міг', 'би', 'приїхати', 'з', 'США', 'Так', 'що', 'посольство', 'США', 'у', 'Москві', 'ймовірно', 'буде', 'поставлено', 'в', 'ситуацію', '1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# і
# ['посольств', 'але', 'і', 'технічному', 'персоналу', 'який', 'міг', 'би', 'приїхати', 'з', 'США', 'Так', 'що', 'посольство', 'США', 'у', 'Москві', 'ймовірно', 'буде', 'поставлено', 'в', 'ситуацію', '1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# Так
# ['з', 'США', 'Так', 'що', 'посольство', 'США', 'у', 'Москві', 'ймовірно', 'буде', 'поставлено', 'в', 'ситуацію', '1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# Тоді
# ['1986', 'року', 'Тоді', 'технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# теж
# ['технічний', 'персонал', 'теж', 'був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# а
# ['був', 'відкликаний', 'а', 'посол', 'Артур', 'Хартман', 'сам', 'сів', 'за', 'кермо', 'службового', 'автомобіля']
# Якщо
# ['принципом', 'паритету']
# тільки
# ['американське', 'посольство', 'тільки', 'готується', 'до', 'паралічу', '-', 'і', 'при', 'цьому', 'власних', 'співробітників', 'у', 'нього', 'ще', 'чимало', '-', 'так', 'посольство', 'Чехії', 'практично', 'є', 'паралізованим', 'після', 'того', 'як', 'Москва', 'вислала', '20', 'чеських', 'дипломатів', 'у', 'відповідь', 'на', 'рішення', 'Праги', 'про', 'висилку', '18', 'росіян', 'які', 'займалися', 'в', 'посольстві', 'Росії', 'шпигунською', 'і', 'диверсійною', 'діяльністю', 'У', 'посольстві', 'Чехії', 'залишилося', 'всього', '5', 'співробітників', 'і', 'міністр', 'закордонних', 'справ', 'цієї', 'країни', 'Якуб', 'Кульганек', 'поставив', 'Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# і
# ['паралічу', '-', 'і', 'при', 'цьому', 'власних', 'співробітників', 'у', 'нього', 'ще', 'чимало', '-', 'так', 'посольство', 'Чехії', 'практично', 'є', 'паралізованим', 'після', 'того', 'як', 'Москва', 'вислала', '20', 'чеських', 'дипломатів', 'у', 'відповідь', 'на', 'рішення', 'Праги', 'про', 'висилку', '18', 'росіян', 'які', 'займалися', 'в', 'посольстві', 'Росії', 'шпигунською', 'і', 'диверсійною', 'діяльністю', 'У', 'посольстві', 'Чехії', 'залишилося', 'всього', '5', 'співробітників', 'і', 'міністр', 'закордонних', 'справ', 'цієї', 'країни', 'Якуб', 'Кульганек', 'поставив', 'Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# ще
# ['у', 'нього', 'ще', 'чимало', '-', 'так', 'посольство', 'Чехії', 'практично', 'є', 'паралізованим', 'після', 'того', 'як', 'Москва', 'вислала', '20', 'чеських', 'дипломатів', 'у', 'відповідь', 'на', 'рішення', 'Праги', 'про', 'висилку', '18', 'росіян', 'які', 'займалися', 'в', 'посольстві', 'Росії', 'шпигунською', 'і', 'диверсійною', 'діяльністю', 'У', 'посольстві', 'Чехії', 'залишилося', 'всього', '5', 'співробітників', 'і', 'міністр', 'закордонних', 'справ', 'цієї', 'країни', 'Якуб', 'Кульганек', 'поставив', 'Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# так
# ['чимало', '-', 'так', 'посольство', 'Чехії', 'практично', 'є', 'паралізованим', 'після', 'того', 'як', 'Москва', 'вислала', '20', 'чеських', 'дипломатів', 'у', 'відповідь', 'на', 'рішення', 'Праги', 'про', 'висилку', '18', 'росіян', 'які', 'займалися', 'в', 'посольстві', 'Росії', 'шпигунською', 'і', 'диверсійною', 'діяльністю', 'У', 'посольстві', 'Чехії', 'залишилося', 'всього', '5', 'співробітників', 'і', 'міністр', 'закордонних', 'справ', 'цієї', 'країни', 'Якуб', 'Кульганек', 'поставив', 'Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# після
# ['є', 'паралізованим', 'після', 'того', 'як', 'Москва', 'вислала', '20', 'чеських', 'дипломатів', 'у', 'відповідь', 'на', 'рішення', 'Праги', 'про', 'висилку', '18', 'росіян', 'які', 'займалися', 'в', 'посольстві', 'Росії', 'шпигунською', 'і', 'диверсійною', 'діяльністю', 'У', 'посольстві', 'Чехії', 'залишилося', 'всього', '5', 'співробітників', 'і', 'міністр', 'закордонних', 'справ', 'цієї', 'країни', 'Якуб', 'Кульганек', 'поставив', 'Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# як
# ['після', 'того', 'як', 'Москва', 'вислала', '20', 'чеських', 'дипломатів', 'у', 'відповідь', 'на', 'рішення', 'Праги', 'про', 'висилку', '18', 'росіян', 'які', 'займалися', 'в', 'посольстві', 'Росії', 'шпигунською', 'і', 'диверсійною', 'діяльністю', 'У', 'посольстві', 'Чехії', 'залишилося', 'всього', '5', 'співробітників', 'і', 'міністр', 'закордонних', 'справ', 'цієї', 'країни', 'Якуб', 'Кульганек', 'поставив', 'Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# і
# ['Росії', 'шпигунською', 'і', 'диверсійною', 'діяльністю', 'У', 'посольстві', 'Чехії', 'залишилося', 'всього', '5', 'співробітників', 'і', 'міністр', 'закордонних', 'справ', 'цієї', 'країни', 'Якуб', 'Кульганек', 'поставив', 'Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# і
# ['5', 'співробітників', 'і', 'міністр', 'закордонних', 'справ', 'цієї', 'країни', 'Якуб', 'Кульганек', 'поставив', 'Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# або
# ['Москві', 'ультиматум:', 'або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# або
# ['буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# ще
# ['Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# і
# ['ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# А
# ['негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# і
# ['у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# Оскільки
# ['інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# ніж
# ['дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# також
# ['були', 'вислані', 'також', 'із', 'Польщі', 'Ну', 'і', 'на', 'цьому', 'тлі', 'затримання', 'українського', 'дипломата', 'у', 'Санкт-Петербурзі', 'його', 'подальша', 'висилка', 'і', 'висилка', 'російського', 'дипломата', 'з', 'Києва', 'виглядають', 'звичайно', 'ж', 'дуже', 'скромною', 'участю', 'України', 'у', 'цій', 'війні', 'посольств', '-', 'якщо', 'тільки', 'не', "пам'ятати", 'про', 'озброєну', 'до', 'зубів', 'орду', 'біля', 'наших', 'кордонів', 'Але', 'у', 'будь-якому', 'випадку', 'ми', 'повинні', 'розуміти', 'що', 'така', 'конфронтація', 'на', 'рівні', 'дипломатичних', 'представництв', '-', 'точний', 'індикатор', 'початку', 'нової', 'холодної', 'війни', 'яка', 'буде', 'супроводжуватися', 'гарячими', 'інцидентами']
# і
# ['Польщі', 'Ну', 'і', 'на', 'цьому', 'тлі', 'затримання', 'українського', 'дипломата', 'у', 'Санкт-Петербурзі', 'його', 'подальша', 'висилка', 'і', 'висилка', 'російського', 'дипломата', 'з', 'Києва', 'виглядають', 'звичайно', 'ж', 'дуже', 'скромною', 'участю', 'України', 'у', 'цій', 'війні', 'посольств', '-', 'якщо', 'тільки', 'не', "пам'ятати", 'про', 'озброєну', 'до', 'зубів', 'орду', 'біля', 'наших', 'кордонів', 'Але', 'у', 'будь-якому', 'випадку', 'ми', 'повинні', 'розуміти', 'що', 'така', 'конфронтація', 'на', 'рівні', 'дипломатичних', 'представництв', '-', 'точний', 'індикатор', 'початку', 'нової', 'холодної', 'війни', 'яка', 'буде', 'супроводжуватися', 'гарячими', 'інцидентами']
# і
# ['подальша', 'висилка', 'і', 'висилка', 'російського', 'дипломата', 'з', 'Києва', 'виглядають', 'звичайно', 'ж', 'дуже', 'скромною', 'участю', 'України', 'у', 'цій', 'війні', 'посольств', '-', 'якщо', 'тільки', 'не', "пам'ятати", 'про', 'озброєну', 'до', 'зубів', 'орду', 'біля', 'наших', 'кордонів', 'Але', 'у', 'будь-якому', 'випадку', 'ми', 'повинні', 'розуміти', 'що', 'така', 'конфронтація', 'на', 'рівні', 'дипломатичних', 'представництв', '-', 'точний', 'індикатор', 'початку', 'нової', 'холодної', 'війни', 'яка', 'буде', 'супроводжуватися', 'гарячими', 'інцидентами']
# якщо
# ['посольств', '-', 'якщо', 'тільки', 'не', "пам'ятати", 'про', 'озброєну', 'до', 'зубів', 'орду', 'біля', 'наших', 'кордонів', 'Але', 'у', 'будь-якому', 'випадку', 'ми', 'повинні', 'розуміти', 'що', 'така', 'конфронтація', 'на', 'рівні', 'дипломатичних', 'представництв', '-', 'точний', 'індикатор', 'початку', 'нової', 'холодної', 'війни', 'яка', 'буде', 'супроводжуватися', 'гарячими', 'інцидентами']
# тільки
# ['-', 'якщо', 'тільки', 'не', "пам'ятати", 'про', 'озброєну', 'до', 'зубів', 'орду', 'біля', 'наших', 'кордонів', 'Але', 'у', 'будь-якому', 'випадку', 'ми', 'повинні', 'розуміти', 'що', 'така', 'конфронтація', 'на', 'рівні', 'дипломатичних', 'представництв', '-', 'точний', 'індикатор', 'початку', 'нової', 'холодної', 'війни', 'яка', 'буде', 'супроводжуватися', 'гарячими', 'інцидентами']
# Але
# ['наших', 'кордонів', 'Але', 'у', 'будь-якому', 'випадку', 'ми', 'повинні', 'розуміти', 'що', 'така', 'конфронтація', 'на', 'рівні', 'дипломатичних', 'представництв', '-', 'точний', 'індикатор', 'початку', 'нової', 'холодної', 'війни', 'яка', 'буде', 'супроводжуватися', 'гарячими', 'інцидентами']
# І
# ['тільки', 'починається']
# тільки
# ['ця', 'війна', 'тільки', 'починається']
# так
# ['сірниками', 'Саме', 'так', 'чиновник', 'який', 'курує', 'український', 'напрямок', 'у', 'адміністрації', 'Путіна', 'прокоментував', 'поїздку', 'президента', 'Володимира', 'Зеленського', 'на', 'Донбас', 'При', 'цьому', 'Козак', 'підкреслив', 'що', 'у', 'Кремлі', 'просто', 'не', 'знають', 'чого', 'від', 'цих', 'дітей', 'з', 'сірниками', 'очікувати']
# і
# ['українського', 'президента', 'і', 'його', 'оточення', 'пояснює', 'ту', 'нахабність', 'з', 'якою', 'останнім', 'часом', 'діють', 'в', 'Кремлі', 'Володимир', 'Путін', 'і', 'його', 'оточення', 'просто', 'не', 'сприймають', 'всерйоз', 'ані', 'Володимира', 'Зеленського', 'ані', 'співробітників', 'українського', 'президента', 'З', 'одного', 'боку', 'вони', 'впевнені', 'в', 'непередбачуваності', 'самого', 'Зеленського', 'і', 'тих', 'хто', 'його', 'оточує', '-', 'звідси', 'і', 'визначення', 'дітей', 'з', 'сірниками', 'З', 'іншого', 'боку', 'як', 'не', 'крути', 'а', 'це', 'все-таки', 'діти', 'А', 'що', 'діти', 'можуть', 'протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# і
# ['Володимир', 'Путін', 'і', 'його', 'оточення', 'просто', 'не', 'сприймають', 'всерйоз', 'ані', 'Володимира', 'Зеленського', 'ані', 'співробітників', 'українського', 'президента', 'З', 'одного', 'боку', 'вони', 'впевнені', 'в', 'непередбачуваності', 'самого', 'Зеленського', 'і', 'тих', 'хто', 'його', 'оточує', '-', 'звідси', 'і', 'визначення', 'дітей', 'з', 'сірниками', 'З', 'іншого', 'боку', 'як', 'не', 'крути', 'а', 'це', 'все-таки', 'діти', 'А', 'що', 'діти', 'можуть', 'протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# і
# ['самого', 'Зеленського', 'і', 'тих', 'хто', 'його', 'оточує', '-', 'звідси', 'і', 'визначення', 'дітей', 'з', 'сірниками', 'З', 'іншого', 'боку', 'як', 'не', 'крути', 'а', 'це', 'все-таки', 'діти', 'А', 'що', 'діти', 'можуть', 'протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# і
# ['-', 'звідси', 'і', 'визначення', 'дітей', 'з', 'сірниками', 'З', 'іншого', 'боку', 'як', 'не', 'крути', 'а', 'це', 'все-таки', 'діти', 'А', 'що', 'діти', 'можуть', 'протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# як
# ['іншого', 'боку', 'як', 'не', 'крути', 'а', 'це', 'все-таки', 'діти', 'А', 'що', 'діти', 'можуть', 'протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# а
# ['не', 'крути', 'а', 'це', 'все-таки', 'діти', 'А', 'що', 'діти', 'можуть', 'протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# А
# ['все-таки', 'діти', 'А', 'що', 'діти', 'можуть', 'протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# окрім
# ['протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# а
# ['українське', 'керівництво', 'а', 'реакція', 'на', 'цей', 'дитячий', 'плач', 'Путін', 'уважно', 'спостерігає', 'за', 'тим', 'як', 'на', 'заяви', 'України', 'про', 'небувалу', 'концентрацію', 'російських', 'військ', 'на', 'кордоні', 'реагують', 'у', 'Вашингтоні', 'та', 'європейських', 'столицях', 'яку', 'допомогу', 'там', 'готові', 'надати', 'в', 'разі', 'російського', 'нападу', 'на', 'нашу', 'країну', 'Російська', 'розвідка', 'аналізує', 'настрої', 'в', 'українському', 'суспільстві', 'і', 'намагається', 'зрозуміти', 'як', 'багато', 'людей', 'будуть', 'готові', 'знову', 'захищати', 'країну', 'на', 'новому', 'етапі', 'агресії', 'Тобто', 'діти', 'дітьми', 'а', 'Путіна', 'цікавить', 'реакція', 'дорослих']
# як
# ['за', 'тим', 'як', 'на', 'заяви', 'України', 'про', 'небувалу', 'концентрацію', 'російських', 'військ', 'на', 'кордоні', 'реагують', 'у', 'Вашингтоні', 'та', 'європейських', 'столицях', 'яку', 'допомогу', 'там', 'готові', 'надати', 'в', 'разі', 'російського', 'нападу', 'на', 'нашу', 'країну', 'Російська', 'розвідка', 'аналізує', 'настрої', 'в', 'українському', 'суспільстві', 'і', 'намагається', 'зрозуміти', 'як', 'багато', 'людей', 'будуть', 'готові', 'знову', 'захищати', 'країну', 'на', 'новому', 'етапі', 'агресії', 'Тобто', 'діти', 'дітьми', 'а', 'Путіна', 'цікавить', 'реакція', 'дорослих']
# та
# ['у', 'Вашингтоні', 'та', 'європейських', 'столицях', 'яку', 'допомогу', 'там', 'готові', 'надати', 'в', 'разі', 'російського', 'нападу', 'на', 'нашу', 'країну', 'Російська', 'розвідка', 'аналізує', 'настрої', 'в', 'українському', 'суспільстві', 'і', 'намагається', 'зрозуміти', 'як', 'багато', 'людей', 'будуть', 'готові', 'знову', 'захищати', 'країну', 'на', 'новому', 'етапі', 'агресії', 'Тобто', 'діти', 'дітьми', 'а', 'Путіна', 'цікавить', 'реакція', 'дорослих']
# і
# ['українському', 'суспільстві', 'і', 'намагається', 'зрозуміти', 'як', 'багато', 'людей', 'будуть', 'готові', 'знову', 'захищати', 'країну', 'на', 'новому', 'етапі', 'агресії', 'Тобто', 'діти', 'дітьми', 'а', 'Путіна', 'цікавить', 'реакція', 'дорослих']
# як
# ['намагається', 'зрозуміти', 'як', 'багато', 'людей', 'будуть', 'готові', 'знову', 'захищати', 'країну', 'на', 'новому', 'етапі', 'агресії', 'Тобто', 'діти', 'дітьми', 'а', 'Путіна', 'цікавить', 'реакція', 'дорослих']
# Тобто
# ['етапі', 'агресії', 'Тобто', 'діти', 'дітьми', 'а', 'Путіна', 'цікавить', 'реакція', 'дорослих']
# а
# ['діти', 'дітьми', 'а', 'Путіна', 'цікавить', 'реакція', 'дорослих']
# Але
# ['чекістської', 'логіки']
# тому
# ['може', 'не', 'тому', 'що', 'Зеленського', 'не', 'можна', 'обдурити', 'або', 'налякати', 'а', 'тому', 'що', 'дії', 'українського', 'президента', 'є', 'хаотичними', 'і', 'непередбачуваними', 'з', 'точки', 'зору', 'чекістської', 'логіки']
# або
# ['можна', 'обдурити', 'або', 'налякати', 'а', 'тому', 'що', 'дії', 'українського', 'президента', 'є', 'хаотичними', 'і', 'непередбачуваними', 'з', 'точки', 'зору', 'чекістської', 'логіки']
# а
# ['або', 'налякати', 'а', 'тому', 'що', 'дії', 'українського', 'президента', 'є', 'хаотичними', 'і', 'непередбачуваними', 'з', 'точки', 'зору', 'чекістської', 'логіки']
# тому
# ['налякати', 'а', 'тому', 'що', 'дії', 'українського', 'президента', 'є', 'хаотичними', 'і', 'непередбачуваними', 'з', 'точки', 'зору', 'чекістської', 'логіки']
# і
# ['є', 'хаотичними', 'і', 'непередбачуваними', 'з', 'точки', 'зору', 'чекістської', 'логіки']
# після
# ['що', 'існувала', 'після', 'президентських', 'виборів', '2019', 'року', 'З', 'іншого', 'боку', 'важко', 'уявити', 'собі', 'на', 'які', 'ще', 'авантюри', 'буде', 'готовий', 'сам', 'Путін', 'якщо', 'вважає', 'що', 'йому', 'протистоятимуть', 'всього', 'лише', 'діти', 'з', 'сірниками']
# ще
# ['на', 'які', 'ще', 'авантюри', 'буде', 'готовий', 'сам', 'Путін', 'якщо', 'вважає', 'що', 'йому', 'протистоятимуть', 'всього', 'лише', 'діти', 'з', 'сірниками']
# якщо
# ['сам', 'Путін', 'якщо', 'вважає', 'що', 'йому', 'протистоятимуть', 'всього', 'лише', 'діти', 'з', 'сірниками']
# після
# ['у', 'ТКГ', 'після', 'закінчення', 'карантину', 'не', 'повернеться', 'до', 'Мінська', 'через', 'ворожу', 'риторику', 'білоруської', 'влади']
# через
# ['до', 'Мінська', 'через', 'ворожу', 'риторику', 'білоруської', 'влади']
# Коли
# ['очевидна', 'логіка', 'Коли', 'у', '2014', 'році', 'вибирали', 'майданчик', 'для', 'переговорів', 'необхідною', 'була', 'країна', 'до', 'якої', 'могли', 'б', 'без', 'проблем', 'приїжджати', 'представники', 'ворогуючих', 'сторін', 'Білорусь', 'незважаючи', 'на', 'обмеженість', 'свого', 'суверенітету', 'і', 'союзницькі', 'відносини', 'з', 'Росією', 'підходила', 'завдяки', 'хорошим', 'відносинам', 'з', 'Україною', 'Хоча', 'і', 'у', 'тій', 'ситуації', 'у', 'мене', 'наприклад', 'немає', 'сумнівів', 'що', 'за', 'українськими', 'делегатами', 'велося', 'постійне', 'спостереження', 'їх', 'розмови', 'записувалися', 'контакти', 'відстежувалися', 'І', 'для', 'цього', 'навіть', 'не', 'потрібно', 'було', 'агентів', 'білоруського', 'КДБ', 'Російські', 'спецслужби', 'відчувають', 'себе', 'в', 'Білорусі', 'як', 'удома']
# і
# ['свого', 'суверенітету', 'і', 'союзницькі', 'відносини', 'з', 'Росією', 'підходила', 'завдяки', 'хорошим', 'відносинам', 'з', 'Україною', 'Хоча', 'і', 'у', 'тій', 'ситуації', 'у', 'мене', 'наприклад', 'немає', 'сумнівів', 'що', 'за', 'українськими', 'делегатами', 'велося', 'постійне', 'спостереження', 'їх', 'розмови', 'записувалися', 'контакти', 'відстежувалися', 'І', 'для', 'цього', 'навіть', 'не', 'потрібно', 'було', 'агентів', 'білоруського', 'КДБ', 'Російські', 'спецслужби', 'відчувають', 'себе', 'в', 'Білорусі', 'як', 'удома']
# Хоча
# ['з', 'Україною', 'Хоча', 'і', 'у', 'тій', 'ситуації', 'у', 'мене', 'наприклад', 'немає', 'сумнівів', 'що', 'за', 'українськими', 'делегатами', 'велося', 'постійне', 'спостереження', 'їх', 'розмови', 'записувалися', 'контакти', 'відстежувалися', 'І', 'для', 'цього', 'навіть', 'не', 'потрібно', 'було', 'агентів', 'білоруського', 'КДБ', 'Російські', 'спецслужби', 'відчувають', 'себе', 'в', 'Білорусі', 'як', 'удома']
# і
# ['Україною', 'Хоча', 'і', 'у', 'тій', 'ситуації', 'у', 'мене', 'наприклад', 'немає', 'сумнівів', 'що', 'за', 'українськими', 'делегатами', 'велося', 'постійне', 'спостереження', 'їх', 'розмови', 'записувалися', 'контакти', 'відстежувалися', 'І', 'для', 'цього', 'навіть', 'не', 'потрібно', 'було', 'агентів', 'білоруського', 'КДБ', 'Російські', 'спецслужби', 'відчувають', 'себе', 'в', 'Білорусі', 'як', 'удома']
# наприклад
# ['у', 'мене', 'наприклад', 'немає', 'сумнівів', 'що', 'за', 'українськими', 'делегатами', 'велося', 'постійне', 'спостереження', 'їх', 'розмови', 'записувалися', 'контакти', 'відстежувалися', 'І', 'для', 'цього', 'навіть', 'не', 'потрібно', 'було', 'агентів', 'білоруського', 'КДБ', 'Російські', 'спецслужби', 'відчувають', 'себе', 'в', 'Білорусі', 'як', 'удома']
# І
# ['контакти', 'відстежувалися', 'І', 'для', 'цього', 'навіть', 'не', 'потрібно', 'було', 'агентів', 'білоруського', 'КДБ', 'Російські', 'спецслужби', 'відчувають', 'себе', 'в', 'Білорусі', 'як', 'удома']
# як
# ['в', 'Білорусі', 'як', 'удома']
# Однак
# ['куди', 'скажуть']
# тоді
# ['скажуть']
# А
# ['з', 'Україною', 'А', 'тепер', 'перестав', 'І', 'ми', 'розуміємо', 'чому', '-', 'після', 'масових', 'протестів', 'білорусів', 'проти', 'фальсифікації', 'підсумків', 'президентських', 'виборів', 'і', 'авторитаризму', 'тупої', 'влади', 'єдиною', 'опорою', 'білоруського', 'режиму', '-', 'крім', 'власних', 'силовиків', '-', 'залишився', 'Кремль', 'З', 'правителя', 'що', 'паразитує', 'на', 'російській', 'економіці', 'Лукашенко', 'перетворився', 'на', 'васала', 'Кремля', 'Ну', 'і', 'окрім', 'того', 'посилилася', 'його', 'власна', 'ненависть', 'до', 'України', '-', 'країни', 'у', 'якій', 'був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# І
# ['тепер', 'перестав', 'І', 'ми', 'розуміємо', 'чому', '-', 'після', 'масових', 'протестів', 'білорусів', 'проти', 'фальсифікації', 'підсумків', 'президентських', 'виборів', 'і', 'авторитаризму', 'тупої', 'влади', 'єдиною', 'опорою', 'білоруського', 'режиму', '-', 'крім', 'власних', 'силовиків', '-', 'залишився', 'Кремль', 'З', 'правителя', 'що', 'паразитує', 'на', 'російській', 'економіці', 'Лукашенко', 'перетворився', 'на', 'васала', 'Кремля', 'Ну', 'і', 'окрім', 'того', 'посилилася', 'його', 'власна', 'ненависть', 'до', 'України', '-', 'країни', 'у', 'якій', 'був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# після
# ['чому', '-', 'після', 'масових', 'протестів', 'білорусів', 'проти', 'фальсифікації', 'підсумків', 'президентських', 'виборів', 'і', 'авторитаризму', 'тупої', 'влади', 'єдиною', 'опорою', 'білоруського', 'режиму', '-', 'крім', 'власних', 'силовиків', '-', 'залишився', 'Кремль', 'З', 'правителя', 'що', 'паразитує', 'на', 'російській', 'економіці', 'Лукашенко', 'перетворився', 'на', 'васала', 'Кремля', 'Ну', 'і', 'окрім', 'того', 'посилилася', 'його', 'власна', 'ненависть', 'до', 'України', '-', 'країни', 'у', 'якій', 'був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# і
# ['президентських', 'виборів', 'і', 'авторитаризму', 'тупої', 'влади', 'єдиною', 'опорою', 'білоруського', 'режиму', '-', 'крім', 'власних', 'силовиків', '-', 'залишився', 'Кремль', 'З', 'правителя', 'що', 'паразитує', 'на', 'російській', 'економіці', 'Лукашенко', 'перетворився', 'на', 'васала', 'Кремля', 'Ну', 'і', 'окрім', 'того', 'посилилася', 'його', 'власна', 'ненависть', 'до', 'України', '-', 'країни', 'у', 'якій', 'був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# і
# ['Кремля', 'Ну', 'і', 'окрім', 'того', 'посилилася', 'його', 'власна', 'ненависть', 'до', 'України', '-', 'країни', 'у', 'якій', 'був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# окрім
# ['Ну', 'і', 'окрім', 'того', 'посилилася', 'його', 'власна', 'ненависть', 'до', 'України', '-', 'країни', 'у', 'якій', 'був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# і
# ['був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# А
# ['до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# і
# ['йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# І
# ['грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# якщо
# ['Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# тому
# ['гідності']
# і
# ['про', 'підтримку', 'і', 'тиск', 'на', 'агресора', 'Ці', 'заяви', 'були', 'зустрінуті', 'з', 'розумінням', 'Президент', 'Сполучених', 'Штатів', 'телефонував', 'президенту', 'України', 'після', 'безпрецедентної', 'серії', 'розмов', 'між', 'високопоставленими', 'українськими', 'та', 'американськими', 'чиновниками', 'Вже', 'сьогодні', 'стало', 'відомо', 'про', 'те', 'що', 'міністр', 'закордонних', 'справ', 'України', 'запрошений', 'до', 'спілкування', 'з', 'міністрами', 'закордонних', 'справ', 'країн', 'Євросоюзу', "З'явилася", 'інформація', 'про', 'можливі', 'тристоронні', 'переговори', 'лідерів', 'Франції', 'Німеччини', 'та', 'України']
# після
# ['президенту', 'України', 'після', 'безпрецедентної', 'серії', 'розмов', 'між', 'високопоставленими', 'українськими', 'та', 'американськими', 'чиновниками', 'Вже', 'сьогодні', 'стало', 'відомо', 'про', 'те', 'що', 'міністр', 'закордонних', 'справ', 'України', 'запрошений', 'до', 'спілкування', 'з', 'міністрами', 'закордонних', 'справ', 'країн', 'Євросоюзу', "З'явилася", 'інформація', 'про', 'можливі', 'тристоронні', 'переговори', 'лідерів', 'Франції', 'Німеччини', 'та', 'України']
# та
# ['високопоставленими', 'українськими', 'та', 'американськими', 'чиновниками', 'Вже', 'сьогодні', 'стало', 'відомо', 'про', 'те', 'що', 'міністр', 'закордонних', 'справ', 'України', 'запрошений', 'до', 'спілкування', 'з', 'міністрами', 'закордонних', 'справ', 'країн', 'Євросоюзу', "З'явилася", 'інформація', 'про', 'можливі', 'тристоронні', 'переговори', 'лідерів', 'Франції', 'Німеччини', 'та', 'України']
# та
# ['Франції', 'Німеччини', 'та', 'України']
# і
# ['те', 'що', 'і', 'на', 'Заході', 'вважають', 'що', 'нове', 'військове', 'вторгнення', 'Росії', 'в', 'Україну', '-', 'а', 'значить', 'нова', 'втрата', 'територій', 'нові', 'людські', 'жертви', 'нові', 'тисячі', 'біженців', '-', 'аж', 'ніяк', 'не', 'є', 'виключеними']
# а
# ['Україну', '-', 'а', 'значить', 'нова', 'втрата', 'територій', 'нові', 'людські', 'жертви', 'нові', 'тисячі', 'біженців', '-', 'аж', 'ніяк', 'не', 'є', 'виключеними']
# І
# ['залишає', 'країну']
# тому
# ['не', 'в', 'тому', 'куди', 'саме', 'Справа', 'в', 'тому', 'що', 'залишає', 'країну']
# тому
# ['Справа', 'в', 'тому', 'що', 'залишає', 'країну']
# і
# ['їх', 'державам', 'і', 'може', 'призвести', 'до', 'війни', 'і', 'жертв', 'глави', 'держав', 'переривають', 'офіційні', 'візити', 'або', 'відпустки', 'і', 'повертаються', 'додому', 'Переривають', 'а', 'не', 'починають']
# і
# ['до', 'війни', 'і', 'жертв', 'глави', 'держав', 'переривають', 'офіційні', 'візити', 'або', 'відпустки', 'і', 'повертаються', 'додому', 'Переривають', 'а', 'не', 'починають']
# або
# ['офіційні', 'візити', 'або', 'відпустки', 'і', 'повертаються', 'додому', 'Переривають', 'а', 'не', 'починають']
# і
# ['або', 'відпустки', 'і', 'повертаються', 'додому', 'Переривають', 'а', 'не', 'починають']
# а
# ['додому', 'Переривають', 'а', 'не', 'починають']
# і
# ['західної', 'дипломатії', 'і', 'громадської', 'думки', 'Про', 'те', 'що', 'ніякої', 'реальної', 'небезпеки', 'немає', 'Що', 'все', 'це', 'була', 'українська', 'вигадка', 'а', 'російські', 'чиновники', 'які', 'стверджували', 'що', 'маневри', 'їхніх', 'збройних', 'сил', 'нікому', 'не', 'загрожують', 'говорили', 'правду', 'І', 'це', 'те', 'що', 'вже', 'сьогодні', 'будуть', 'говорити', 'російські', 'дипломати', 'своїм', 'співрозмовникам', 'у', 'всіх', 'країнах', 'світу:', 'якщо', 'українці', 'дійсно', 'вважали', 'б', 'що', 'на', 'них', 'нападуть', 'хіба', 'президент', 'України', 'як', 'ні', 'в', 'чому', 'не', 'бувало', 'відправився', 'б', 'з', 'візитом', 'Звичайно', 'ні', 'Київ', 'вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# а
# ['українська', 'вигадка', 'а', 'російські', 'чиновники', 'які', 'стверджували', 'що', 'маневри', 'їхніх', 'збройних', 'сил', 'нікому', 'не', 'загрожують', 'говорили', 'правду', 'І', 'це', 'те', 'що', 'вже', 'сьогодні', 'будуть', 'говорити', 'російські', 'дипломати', 'своїм', 'співрозмовникам', 'у', 'всіх', 'країнах', 'світу:', 'якщо', 'українці', 'дійсно', 'вважали', 'б', 'що', 'на', 'них', 'нападуть', 'хіба', 'президент', 'України', 'як', 'ні', 'в', 'чому', 'не', 'бувало', 'відправився', 'б', 'з', 'візитом', 'Звичайно', 'ні', 'Київ', 'вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# І
# ['говорили', 'правду', 'І', 'це', 'те', 'що', 'вже', 'сьогодні', 'будуть', 'говорити', 'російські', 'дипломати', 'своїм', 'співрозмовникам', 'у', 'всіх', 'країнах', 'світу:', 'якщо', 'українці', 'дійсно', 'вважали', 'б', 'що', 'на', 'них', 'нападуть', 'хіба', 'президент', 'України', 'як', 'ні', 'в', 'чому', 'не', 'бувало', 'відправився', 'б', 'з', 'візитом', 'Звичайно', 'ні', 'Київ', 'вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# якщо
# ['країнах', 'світу:', 'якщо', 'українці', 'дійсно', 'вважали', 'б', 'що', 'на', 'них', 'нападуть', 'хіба', 'президент', 'України', 'як', 'ні', 'в', 'чому', 'не', 'бувало', 'відправився', 'б', 'з', 'візитом', 'Звичайно', 'ні', 'Київ', 'вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# хіба
# ['них', 'нападуть', 'хіба', 'президент', 'України', 'як', 'ні', 'в', 'чому', 'не', 'бувало', 'відправився', 'б', 'з', 'візитом', 'Звичайно', 'ні', 'Київ', 'вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# як
# ['президент', 'України', 'як', 'ні', 'в', 'чому', 'не', 'бувало', 'відправився', 'б', 'з', 'візитом', 'Звичайно', 'ні', 'Київ', 'вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# тому
# ['вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# Тому
# ['Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# та
# ['у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# Тому
# ['з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# і
# ['ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# і
# ['уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# як
# ['американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# І
# ['Є', 'сумніви']
# і
# ['можновладцями']
# і
# ['є', 'приголомшливий', 'і', 'непоправний', 'провал', 'української', 'політики', 'і', 'дипломатії', 'після', 'очевидних', 'успіхів', 'останніх', 'тижнів', 'Обиватель', 'прихильник', 'Зеленського', '-', 'як', 'і', 'сам', 'Зеленський', '-', 'навіть', 'не', 'зрозуміє', 'який', 'це', 'провал', 'Тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'взагалі', 'нічого', 'не', 'розуміють', 'у', 'реальному', 'житті', 'Опонент', 'Зеленського', 'вирішить', 'що', 'президент', 'відправився', 'до', 'Катару', 'не', 'дарма', '-', 'а', 'на', 'таємні', 'переговори', 'із', 'російськими', 'можновладцями']
# і
# ['української', 'політики', 'і', 'дипломатії', 'після', 'очевидних', 'успіхів', 'останніх', 'тижнів', 'Обиватель', 'прихильник', 'Зеленського', '-', 'як', 'і', 'сам', 'Зеленський', '-', 'навіть', 'не', 'зрозуміє', 'який', 'це', 'провал', 'Тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'взагалі', 'нічого', 'не', 'розуміють', 'у', 'реальному', 'житті', 'Опонент', 'Зеленського', 'вирішить', 'що', 'президент', 'відправився', 'до', 'Катару', 'не', 'дарма', '-', 'а', 'на', 'таємні', 'переговори', 'із', 'російськими', 'можновладцями']
# після
# ['і', 'дипломатії', 'після', 'очевидних', 'успіхів', 'останніх', 'тижнів', 'Обиватель', 'прихильник', 'Зеленського', '-', 'як', 'і', 'сам', 'Зеленський', '-', 'навіть', 'не', 'зрозуміє', 'який', 'це', 'провал', 'Тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'взагалі', 'нічого', 'не', 'розуміють', 'у', 'реальному', 'житті', 'Опонент', 'Зеленського', 'вирішить', 'що', 'президент', 'відправився', 'до', 'Катару', 'не', 'дарма', '-', 'а', 'на', 'таємні', 'переговори', 'із', 'російськими', 'можновладцями']
# як
# ['Зеленського', '-', 'як', 'і', 'сам', 'Зеленський', '-', 'навіть', 'не', 'зрозуміє', 'який', 'це', 'провал', 'Тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'взагалі', 'нічого', 'не', 'розуміють', 'у', 'реальному', 'житті', 'Опонент', 'Зеленського', 'вирішить', 'що', 'президент', 'відправився', 'до', 'Катару', 'не', 'дарма', '-', 'а', 'на', 'таємні', 'переговори', 'із', 'російськими', 'можновладцями']
# і
# ['-', 'як', 'і', 'сам', 'Зеленський', '-', 'навіть', 'не', 'зрозуміє', 'який', 'це', 'провал', 'Тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'взагалі', 'нічого', 'не', 'розуміють', 'у', 'реальному', 'житті', 'Опонент', 'Зеленського', 'вирішить', 'що', 'президент', 'відправився', 'до', 'Катару', 'не', 'дарма', '-', 'а', 'на', 'таємні', 'переговори', 'із', 'російськими', 'можновладцями']
# Тому
# ['це', 'провал', 'Тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'взагалі', 'нічого', 'не', 'розуміють', 'у', 'реальному', 'житті', 'Опонент', 'Зеленського', 'вирішить', 'що', 'президент', 'відправився', 'до', 'Катару', 'не', 'дарма', '-', 'а', 'на', 'таємні', 'переговори', 'із', 'російськими', 'можновладцями']
# а
# ['дарма', '-', 'а', 'на', 'таємні', 'переговори', 'із', 'російськими', 'можновладцями']
# А
# ['і', 'ні']
# насправді
# ['ні']
# тому
# ['Катару', 'просто', 'тому', 'що', 'відправився', 'до', 'Катару', 'Просто', 'тому', 'що', 'йому', 'так', 'захотілося', 'Просто', 'тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'не', 'відчувають', 'ніякої', 'відповідальності', 'за', 'нашу', 'країну', 'Катар', '-', 'так', 'Катар', 'чому', 'б', 'і', 'ні']
# тому
# ['Катару', 'Просто', 'тому', 'що', 'йому', 'так', 'захотілося', 'Просто', 'тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'не', 'відчувають', 'ніякої', 'відповідальності', 'за', 'нашу', 'країну', 'Катар', '-', 'так', 'Катар', 'чому', 'б', 'і', 'ні']
# так
# ['що', 'йому', 'так', 'захотілося', 'Просто', 'тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'не', 'відчувають', 'ніякої', 'відповідальності', 'за', 'нашу', 'країну', 'Катар', '-', 'так', 'Катар', 'чому', 'б', 'і', 'ні']
# тому
# ['захотілося', 'Просто', 'тому', 'що', 'ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'не', 'відчувають', 'ніякої', 'відповідальності', 'за', 'нашу', 'країну', 'Катар', '-', 'так', 'Катар', 'чому', 'б', 'і', 'ні']
# так
# ['Катар', '-', 'так', 'Катар', 'чому', 'б', 'і', 'ні']
# і
# ['чому', 'б', 'і', 'ні']
# І
# ['нашій', 'землі']
# коли
# ['особливо', 'довіряти', 'коли', 'ми', 'будемо', 'про', 'неї', 'говорити', 'І', 'росіяни', 'можуть', 'відчувати', 'себе', 'набагато', 'більш', 'впевнено', '-', 'і', 'біля', 'наших', 'кордонів', 'і', 'на', 'нашій', 'землі']
# І
# ['неї', 'говорити', 'І', 'росіяни', 'можуть', 'відчувати', 'себе', 'набагато', 'більш', 'впевнено', '-', 'і', 'біля', 'наших', 'кордонів', 'і', 'на', 'нашій', 'землі']
# і
# ['впевнено', '-', 'і', 'біля', 'наших', 'кордонів', 'і', 'на', 'нашій', 'землі']
# і
# ['наших', 'кордонів', 'і', 'на', 'нашій', 'землі']
# і
# ['кричати', 'вовки', 'і', 'демонструвати', 'що', 'сам', 'ти', 'цих', 'вовків', 'не', 'помічаєш']

# %%
for e in range (len(text)):
    for w in two_words:
        if w in text[e]:
            print(w)
            print(tokenized[e])
            print('--')
            for tok in range(len(tokenized[e])):
                if w.split(' ')[0]==tokenized[e][tok].lower() and w.split(' ')[1]==tokenized[e][tok+1].lower():
                    print(tokenized[e][tok-2:tok+4])
                    matched.append(tokenized[e][tok])
            print('\n')

#for the ne tilki a i exception
#!!add але/а й/і as variants
for e in range (len(text)):
    if 'не тільки' in text[e]:
        print(text[e])
        if ' але й ' in text[e] or ' a й ' or ' але і 'in text[e] or ' а і ' in text[e]:
            print('yes')
            for tok in range(len(tokenized[e])):
                if 'не'==tokenized[e][tok].lower() and 'тільки'==tokenized[e][tok+1].lower():
                    print(tokenized[e][tok-2:tok+8])
                    find=[i for i in range(len(tokenized[e][tok:]))if tokenized[e][tok:][i]=='а' or tokenized[e][tok:][i]=='але']
                    if find!=[]:
                        print(tokenized[e][tok:tok+2],tokenized[e][find[0]+tok:find[0]+tok+2])
                        matched.append([tokenized[e][tok:tok+2],tokenized[e][find[0]+tok:find[0]+tok+2]])
# Out:
# тому що
# ['Але', 'сам', 'по', 'собі', 'Зеленський', 'не', 'може', 'ані', 'зупинити', 'Путіна', 'ані', 'з', 'ним', 'домовитися', 'Російський', 'президент', 'уже', 'зрозумів', 'що', 'не', 'може', 'ані', 'обдурити', 'ані', 'налякати', 'українського', 'колегу', 'Не', 'може', 'не', 'тому', 'що', 'Зеленського', 'не', 'можна', 'обдурити', 'або', 'налякати', 'а', 'тому', 'що', 'дії', 'українського', 'президента', 'є', 'хаотичними', 'і', 'непередбачуваними', 'з', 'точки', 'зору', 'чекістської', 'логіки']
# --
# ['може', 'не', 'тому', 'що', 'Зеленського', 'не']
# ['налякати', 'а', 'тому', 'що', 'дії', 'українського']
#
#
# незважаючи на
# ['У', 'цьому', 'є', 'очевидна', 'логіка', 'Коли', 'у', '2014', 'році', 'вибирали', 'майданчик', 'для', 'переговорів', 'необхідною', 'була', 'країна', 'до', 'якої', 'могли', 'б', 'без', 'проблем', 'приїжджати', 'представники', 'ворогуючих', 'сторін', 'Білорусь', 'незважаючи', 'на', 'обмеженість', 'свого', 'суверенітету', 'і', 'союзницькі', 'відносини', 'з', 'Росією', 'підходила', 'завдяки', 'хорошим', 'відносинам', 'з', 'Україною', 'Хоча', 'і', 'у', 'тій', 'ситуації', 'у', 'мене', 'наприклад', 'немає', 'сумнівів', 'що', 'за', 'українськими', 'делегатами', 'велося', 'постійне', 'спостереження', 'їх', 'розмови', 'записувалися', 'контакти', 'відстежувалися', 'І', 'для', 'цього', 'навіть', 'не', 'потрібно', 'було', 'агентів', 'білоруського', 'КДБ', 'Російські', 'спецслужби', 'відчувають', 'себе', 'в', 'Білорусі', 'як', 'удома']
# --
# ['сторін', 'Білорусь', 'незважаючи', 'на', 'обмеженість', 'свого']
#
#
# окрім того
# ['Однак', 'тоді', 'білоруський', 'президент', 'Олександр', 'Лукашенко', 'не', 'переставав', 'говорити', 'про', 'дружні', 'стосунки', 'з', 'Україною', 'А', 'тепер', 'перестав', 'І', 'ми', 'розуміємо', 'чому', '-', 'після', 'масових', 'протестів', 'білорусів', 'проти', 'фальсифікації', 'підсумків', 'президентських', 'виборів', 'і', 'авторитаризму', 'тупої', 'влади', 'єдиною', 'опорою', 'білоруського', 'режиму', '-', 'крім', 'власних', 'силовиків', '-', 'залишився', 'Кремль', 'З', 'правителя', 'що', 'паразитує', 'на', 'російській', 'економіці', 'Лукашенко', 'перетворився', 'на', 'васала', 'Кремля', 'Ну', 'і', 'окрім', 'того', 'посилилася', 'його', 'власна', 'ненависть', 'до', 'України', '-', 'країни', 'у', 'якій', 'був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# --
# ['Ну', 'і', 'окрім', 'того', 'посилилася', 'його']
#
#
# крім того
# ['Однак', 'тоді', 'білоруський', 'президент', 'Олександр', 'Лукашенко', 'не', 'переставав', 'говорити', 'про', 'дружні', 'стосунки', 'з', 'Україною', 'А', 'тепер', 'перестав', 'І', 'ми', 'розуміємо', 'чому', '-', 'після', 'масових', 'протестів', 'білорусів', 'проти', 'фальсифікації', 'підсумків', 'президентських', 'виборів', 'і', 'авторитаризму', 'тупої', 'влади', 'єдиною', 'опорою', 'білоруського', 'режиму', '-', 'крім', 'власних', 'силовиків', '-', 'залишився', 'Кремль', 'З', 'правителя', 'що', 'паразитує', 'на', 'російській', 'економіці', 'Лукашенко', 'перетворився', 'на', 'васала', 'Кремля', 'Ну', 'і', 'окрім', 'того', 'посилилася', 'його', 'власна', 'ненависть', 'до', 'України', '-', 'країни', 'у', 'якій', 'був', 'Майдан', 'і', 'громадянам', 'якої', 'вдалося', 'відправити', 'свого', 'Лукашенка', 'до', 'Ростова', 'А', 'білоруському', 'диктатору', 'не', 'хочеться', 'до', 'Ростова', 'йому', 'потрібно', 'і', 'далі', 'грабувати', 'Білорусь', 'І', 'якщо', 'за', 'це', 'потрібно', 'лягти', 'під', 'Путіна', '-', 'проблем', 'немає', 'Ляже', 'куди', 'скажуть']
# --
#
#
# тому що
# ['Про', 'що', 'свідчить', 'така', 'поведінка', 'Зеленського', 'з', 'точки', 'зору', 'західної', 'дипломатії', 'і', 'громадської', 'думки', 'Про', 'те', 'що', 'ніякої', 'реальної', 'небезпеки', 'немає', 'Що', 'все', 'це', 'була', 'українська', 'вигадка', 'а', 'російські', 'чиновники', 'які', 'стверджували', 'що', 'маневри', 'їхніх', 'збройних', 'сил', 'нікому', 'не', 'загрожують', 'говорили', 'правду', 'І', 'це', 'те', 'що', 'вже', 'сьогодні', 'будуть', 'говорити', 'російські', 'дипломати', 'своїм', 'співрозмовникам', 'у', 'всіх', 'країнах', 'світу:', 'якщо', 'українці', 'дійсно', 'вважали', 'б', 'що', 'на', 'них', 'нападуть', 'хіба', 'президент', 'України', 'як', 'ні', 'в', 'чому', 'не', 'бувало', 'відправився', 'б', 'з', 'візитом', 'Звичайно', 'ні', 'Київ', 'вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# --
# ['вас', 'обманює', 'тому', 'що', 'не', 'хоче']
# ['Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського']
# ['з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже']
#
#
# Одночасно Росія намагається паралізувати роботу американських дипломатичних представництв. МЗС Росії приступив до оформлення рішення про заборону дипмісіям США наймати на роботу громадян Росії і, між іншим, інших країн теж. Якщо враховувати, що американські дипломатичні представництва, як правило, наймають технічних співробітників на місці, це стане серйозною проблемою. При цьому Росія відмовляє у візах не тільки співробітникам посольств, але і технічному персоналу, який міг би приїхати з США. Так що посольство США у Москві, ймовірно, буде поставлено в ситуацію 1986 року. Тоді технічний персонал теж був відкликаний, а посол Артур Хартман сам сів за кермо службового автомобіля.
# yes
# ['у', 'візах', 'не', 'тільки', 'співробітникам', 'посольств', 'але', 'і', 'технічному', 'персоналу']
# ['не', 'тільки'] ['але', 'і']

# %%
#[['ані', 'ані'], ['ні', 'ні'], ['чим', 'тим'], ['або', 'або']]
done=[]
cpt=0
for e  in tokenized:
    for w in range(len(e)):
        find=[t for t in two_parted if t[0]==e[w]]
        if find!=[]:
            if find[0][1] in e[w:]:
                find2=[e[w:][i] for i in range(len(e[w:]))if e[w:][i]==find[0][1]]
                if find2!=[] and len(find2)>1:
                    cpt=0
                    for word in e[w:]:
                        if word in done:
                            cpt+=1
                    if cpt==len(e[w:]):
                        pass
                    else:
                        matched.append(find2)
                        print(find2)
                        print(e[w:])
                        for word in e[w:]:
                            done.append(word)
                    cpt+=0
# Out:
# ['або', 'або']
# ['або', 'висланих', 'дипломатів', 'буде', 'повернуто', 'або', 'Прага', 'вишле', 'ще', 'одну', 'групу', 'росіян', 'щоб', 'у', 'російському', 'посольстві', 'залишилося', 'стільки', 'ж', 'скільки', 'і', 'в', 'чеському', 'Зрозуміло', 'Кремль', 'ультиматум', 'Кульганека', 'негайно', 'відкинув', 'А', 'це', 'означає', 'що', 'справа', 'йде', 'до', 'закриття', 'посольств', 'у', 'Москві', 'і', 'в', 'Празі', 'Що', 'в', 'принципі', 'в', 'інтересах', 'Чехії', 'Оскільки', 'в', 'російському', 'посольстві', 'був', 'куди', 'більший', 'дипломатичний', 'персонал', 'ніж', 'у', 'чеському', 'на', 'новому', 'етапі', 'дипломатів', 'можна', 'буде', 'набирати', 'за', 'принципом', 'паритету']
# ['ані', 'ані']
# ['ані', 'Володимира', 'Зеленського', 'ані', 'співробітників', 'українського', 'президента', 'З', 'одного', 'боку', 'вони', 'впевнені', 'в', 'непередбачуваності', 'самого', 'Зеленського', 'і', 'тих', 'хто', 'його', 'оточує', '-', 'звідси', 'і', 'визначення', 'дітей', 'з', 'сірниками', 'З', 'іншого', 'боку', 'як', 'не', 'крути', 'а', 'це', 'все-таки', 'діти', 'А', 'що', 'діти', 'можуть', 'протиставити', 'дорослим', 'окрім', 'гучного', 'плачу']
# ['ані', 'ані', 'ані', 'ані']
# ['ані', 'зупинити', 'Путіна', 'ані', 'з', 'ним', 'домовитися', 'Російський', 'президент', 'уже', 'зрозумів', 'що', 'не', 'може', 'ані', 'обдурити', 'ані', 'налякати', 'українського', 'колегу', 'Не', 'може', 'не', 'тому', 'що', 'Зеленського', 'не', 'можна', 'обдурити', 'або', 'налякати', 'а', 'тому', 'що', 'дії', 'українського', 'президента', 'є', 'хаотичними', 'і', 'непередбачуваними', 'з', 'точки', 'зору', 'чекістської', 'логіки']
# ['ні', 'ні']
# ['ні', 'в', 'чому', 'не', 'бувало', 'відправився', 'б', 'з', 'візитом', 'Звичайно', 'ні', 'Київ', 'вас', 'обманює', 'тому', 'що', 'не', 'хоче', 'виконувати', 'Мінські', 'угоди', 'Тому', 'що', 'у', 'Зеленського', 'та', 'його', 'покровителів-олігархів', 'свої', 'особисті', 'рахунки', 'з', 'Медведчуком', 'Тому', 'що', 'Зеленському', 'дуже', 'потрібно', 'було', 'щоб', 'йому', 'подзвонив', 'Байден', '-', 'ось', 'вони', 'і', 'використовували', 'цю', 'уявну', 'загрозу', 'і', 'домоглися', 'свого', 'Вони', 'просто', 'вас', 'американців', 'розвели', 'як', 'лохів', 'заради', 'самозамилування', 'свого', 'президента', 'Отакої']
# ['ані', 'ані', 'ані']
# ['ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'взагалі', 'нічого', 'не', 'розуміють', 'у', 'реальному', 'житті', 'Опонент', 'Зеленського', 'вирішить', 'що', 'президент', 'відправився', 'до', 'Катару', 'не', 'дарма', '-', 'а', 'на', 'таємні', 'переговори', 'із', 'російськими', 'можновладцями']
# ['ані', 'ані', 'ані']
# ['ані', 'сам', 'Зеленський', 'ані', 'його', 'помічники', 'ані', 'його', 'прихильники', 'не', 'відчувають', 'ніякої', 'відповідальності', 'за', 'нашу', 'країну', 'Катар', '-', 'так', 'Катар', 'чому', 'б', 'і', 'ні']

# %%
print(matched)
# Out:
# ['після', 'як', 'і', 'після', 'як', 'як', 'Одночасно', 'і', 'теж', 'Якщо', 'як', 'тільки', 'але', 'і', 'Так', 'Тоді', 'теж', 'а', 'Якщо', 'тільки', 'і', 'ще', 'так', 'після', 'як', 'і', 'і', 'або', 'або', 'ще', 'і', 'А', 'і', 'Оскільки', 'ніж', 'також', 'і', 'і', 'якщо', 'тільки', 'Але', 'І', 'тільки', 'так', 'і', 'і', 'і', 'і', 'як', 'а', 'А', 'окрім', 'а', 'як', 'та', 'і', 'як', 'Тобто', 'а', 'Але', 'тому', 'або', 'а', 'тому', 'і', 'після', 'ще', 'якщо', 'після', 'через', 'Коли', 'і', 'Хоча', 'і', 'наприклад', 'І', 'як', 'Однак', 'тоді', 'А', 'І', 'після', 'і', 'і', 'окрім', 'і', 'А', 'і', 'І', 'якщо', 'тому', 'і', 'після', 'та', 'та', 'і', 'а', 'І', 'тому', 'тому', 'і', 'і', 'або', 'і', 'а', 'і', 'а', 'І', 'якщо', 'хіба', 'як', 'тому', 'Тому', 'та', 'Тому', 'і', 'і', 'як', 'І', 'і', 'і', 'і', 'після', 'як', 'і', 'Тому', 'а', 'А', 'насправді', 'тому', 'тому', 'так', 'тому', 'так', 'і', 'І', 'коли', 'І', 'і', 'і', 'і', 'тому', 'тому', 'незважаючи', 'окрім', 'тому', 'Тому', 'Тому', [['не', 'тільки'], ['але', 'і']], ['або', 'або'], ['ані', 'ані'], ['ані', 'ані', 'ані', 'ані'], ['ні', 'ні'], ['ані', 'ані', 'ані'], ['ані', 'ані', 'ані']]
